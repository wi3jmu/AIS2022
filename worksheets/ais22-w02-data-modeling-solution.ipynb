# %% [markdown]
# <a href="https://www.kaggle.com/code/matjes/ais22-w02-data-modeling-solution?scriptVersionId=94752127" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# *Analytical Information Systems*
#
# # Data Modeling
#
# Matthias Griebel / Nico Elbert<br>
# Chair of Information Systems and Business Analytics
#
# SS 2022
#
# ***
# # Table of Contents
#
# * [1. Recap: Entity-Relationship Model](#em_model)
# * [2. Exercises](#exercises)
#     * [2.1. Exam AIS WS 2020/2021, Question 1](#ss18)
#     * [2.2. Exam AIS WS 2021/2022, Question 1](#ws2122)
#
# ***
#
# __This Tutorial covers the architectural compoments of ARIS (Architecture of Integrated Information Systems)__
#
# The ARIS concept ensures that an enterprise information system can completely meet its requirements.
#
# <img src="https://github.com/matjesg/AIS_2019/raw/master/notebooks/images/01/aris.png" width="500">
#
#
# ## 1. Entity-Relationship Model<a id="em_model"></a>
#
# ***Recap***
#
# *From [wikipedia](https://en.wikipedia.org/wiki/Entity%E2%80%93relationship_model)*: An entity–relationship model (or ER model) describes interrelated things of interest in a specific domain of knowledge. A basic ER model is composed of entity types (which classify the things of interest) and specifies relationships that can exist between entities (instances of those entity types).
#
# The main components of an ER Model are:
# - Entity: Entirety of similar objects
# - Relationship: Entirety of relationships between object
# - Attribute: Property of an entity or relationship type
#     - Key attributes uniquely identify an entity
# - Cardinalities: The number of times an entity of an entity set participates in a relationship
#
# <span style="color:red">***Your turn***</span>
#
# ****
#
# ## 2. Exercises<a id="exercises"></a>
#
# ## 2.1. Exam AIS WS 2020/2021, Question 1<a id="ss18"></a>
#
# Vaccinations play a key role to fight and end the ongoing COVID-19 pandemic. To this end, vaccination centers are established. Vaccination centers handle a multitude of processes and interact with numerous partners:
#
# - Appointments specify a certain date-time and are identified by an ID. They use a dose and serve a patient. Furthermore, successful completion of an appointment has to be tracked.
# - Doses are characterized by the production lot which in turn specifies the ID, the manufacturer and the date-time.
# - Patients provide their contact information and their social security number.
#
# Please create an Entity-Relationship diagram that captures this information about the vaccination process. Be certain to indicate cardinality constraints as well as primary keys (underline attributes).

# %% [markdown]
# ![__results___1_0.png](attachment:e402ad5e-4a0c-40fe-b272-7a6daa230929.png)

# %% [markdown]
# ## 2.1. Exam AIS WS 2021/2022, Question 1<a id="ws2122"></a>
#
# **a)**
# In international civil aviation there are multiple Airlines.
# * An Airline owns multiple aircrafts, which are each identified by a unique aircraft registration.
# * Each aircraft is of a specific aircraft type, identified by the manufacturer and model.
# * Every airline offers multiple flights with a specific airplane.
# * Each flight has one specific airport as origin and one specific airport as destination.
# * For every route and departure time of every airline there is one unique flight code which can be assigned to a specific flight only once a day.
# * Airports are identified by an airport code. Due to available infrastructure and landing strip length not every aircraft type is approved for every airport.
#
# Please complete this Entity-Relationship diagram that captures this information about the relationships in civil aviation. Be certain to indicate cardinality constraints as well as primary keys (underline attributes).

# %% [markdown]
# ![2022_Q1_ER_Model_solution.png](attachment:549f3528-4e24-4c0f-891a-4f3904f74742.png)

# %% [markdown]
# **b)** The ER-model is obviously not an implementation but a conceptual model.
# How is the ER model typically instantiated in a database system?

# %%
# Using a relational model

# %% [markdown]
# **c)** In the instantiation tables play a central role. Discuss the following
# statement: “Tables represent entitities.” Use the data model above to exemplify
# your reasoning.

# %%
# Every entity will typically get a table. 
# However, for certain types of relationships one needs so called Helper table e.g. "approvements" to connect the tables aircraft type and airport.
